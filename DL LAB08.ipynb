# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np

# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

# Reshape for CNN
X_train_cnn = X_train.reshape(-1,28,28,1)
X_test_cnn = X_test.reshape(-1,28,28,1)

# Batch sizes and epochs to test
batch_sizes = [32, 64, 128, 256]
epochs_list = [10, 15, 20]

for batch in batch_sizes:
    for ep in epochs_list:

        print("\n==============================")
        print(f"Training with Batch Size = {batch}, Epochs = {ep}")
        print("==============================")

        # Build model
        model = Sequential([
            Conv2D(32, (3,3), activation='relu', input_shape=(28,28,1)),
            MaxPooling2D((2,2)),

            Conv2D(64, (3,3), activation='relu'),
            MaxPooling2D((2,2)),

            Flatten(),

            Dense(128, activation='relu'),
            Dense(10, activation='softmax')
        ])

        model.compile(optimizer='adam',
                      loss='sparse_categorical_crossentropy',
                      metrics=['accuracy'])

        model.summary()

        # Train model
        model.fit(X_train_cnn, y_train,
                  epochs=ep,
                  batch_size=batch,
                  validation_split=0.1,
                  verbose=1)

        # Evaluate model
        test_loss, test_acc = model.evaluate(X_test_cnn, y_test)

        print(f"Batch Size: {batch}, Epochs: {ep}")
        print("Test Accuracy:", test_acc)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# ==============================
# Training with Batch Size = 32, Epochs = 10
# ==============================
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 57s 33ms/step - accuracy: 0.9575 - loss: 0.1392 - val_accuracy: 0.9878 - val_loss: 0.0409
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9860 - loss: 0.0447 - val_accuracy: 0.9838 - val_loss: 0.0491
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9901 - loss: 0.0306 - val_accuracy: 0.9885 - val_loss: 0.0394
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - accuracy: 0.9926 - loss: 0.0221 - val_accuracy: 0.9910 - val_loss: 0.0366
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 32ms/step - accuracy: 0.9946 - loss: 0.0166 - val_accuracy: 0.9910 - val_loss: 0.0316
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9957 - loss: 0.0127 - val_accuracy: 0.9917 - val_loss: 0.0354
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 32ms/step - accuracy: 0.9969 - loss: 0.0089 - val_accuracy: 0.9907 - val_loss: 0.0402
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 84s 34ms/step - accuracy: 0.9968 - loss: 0.0096 - val_accuracy: 0.9923 - val_loss: 0.0415
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 63s 37ms/step - accuracy: 0.9973 - loss: 0.0082 - val_accuracy: 0.9922 - val_loss: 0.0332
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 33ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.9933 - val_loss: 0.0384
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9915 - loss: 0.0374
# Batch Size: 32, Epochs: 10
# Test Accuracy: 0.9915000200271606
#
# ==============================
# Training with Batch Size = 32, Epochs = 15
# ==============================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 56s 32ms/step - accuracy: 0.9566 - loss: 0.1416 - val_accuracy: 0.9843 - val_loss: 0.0539
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 33ms/step - accuracy: 0.9849 - loss: 0.0475 - val_accuracy: 0.9868 - val_loss: 0.0401
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9897 - loss: 0.0327 - val_accuracy: 0.9858 - val_loss: 0.0454
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 81s 32ms/step - accuracy: 0.9931 - loss: 0.0227 - val_accuracy: 0.9885 - val_loss: 0.0405
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 82s 32ms/step - accuracy: 0.9937 - loss: 0.0182 - val_accuracy: 0.9897 - val_loss: 0.0379
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9956 - loss: 0.0135 - val_accuracy: 0.9910 - val_loss: 0.0379
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9963 - loss: 0.0107 - val_accuracy: 0.9918 - val_loss: 0.0361
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 56s 33ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.9907 - val_loss: 0.0374
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9974 - loss: 0.0073 - val_accuracy: 0.9918 - val_loss: 0.0422
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 32ms/step - accuracy: 0.9980 - loss: 0.0063 - val_accuracy: 0.9920 - val_loss: 0.0454
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 32ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9918 - val_loss: 0.0379
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 33ms/step - accuracy: 0.9980 - loss: 0.0057 - val_accuracy: 0.9920 - val_loss: 0.0461
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 80s 32ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9913 - val_loss: 0.0445
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9986 - loss: 0.0045 - val_accuracy: 0.9905 - val_loss: 0.0496
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 32ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.9917 - val_loss: 0.0507
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9896 - loss: 0.0530
# Batch Size: 32, Epochs: 15
# Test Accuracy: 0.9896000027656555
#
# ==============================
# Training with Batch Size = 32, Epochs = 20
# ==============================
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 58s 33ms/step - accuracy: 0.9584 - loss: 0.1348 - val_accuracy: 0.9850 - val_loss: 0.0473
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 57s 34ms/step - accuracy: 0.9862 - loss: 0.0447 - val_accuracy: 0.9897 - val_loss: 0.0382
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 56s 33ms/step - accuracy: 0.9902 - loss: 0.0311 - val_accuracy: 0.9903 - val_loss: 0.0364
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 80s 32ms/step - accuracy: 0.9932 - loss: 0.0218 - val_accuracy: 0.9908 - val_loss: 0.0367
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 32ms/step - accuracy: 0.9948 - loss: 0.0163 - val_accuracy: 0.9897 - val_loss: 0.0404
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9958 - loss: 0.0126 - val_accuracy: 0.9917 - val_loss: 0.0410
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 32ms/step - accuracy: 0.9963 - loss: 0.0100 - val_accuracy: 0.9910 - val_loss: 0.0434
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 32ms/step - accuracy: 0.9970 - loss: 0.0085 - val_accuracy: 0.9890 - val_loss: 0.0477
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 31ms/step - accuracy: 0.9974 - loss: 0.0078 - val_accuracy: 0.9903 - val_loss: 0.0488
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 83s 32ms/step - accuracy: 0.9984 - loss: 0.0048 - val_accuracy: 0.9902 - val_loss: 0.0604
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 31ms/step - accuracy: 0.9978 - loss: 0.0071 - val_accuracy: 0.9908 - val_loss: 0.0443
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 53s 31ms/step - accuracy: 0.9981 - loss: 0.0051 - val_accuracy: 0.9913 - val_loss: 0.0511
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9925 - val_loss: 0.0444
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9986 - loss: 0.0040 - val_accuracy: 0.9905 - val_loss: 0.0518
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 54s 32ms/step - accuracy: 0.9987 - loss: 0.0035 - val_accuracy: 0.9895 - val_loss: 0.0770
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 32ms/step - accuracy: 0.9982 - loss: 0.0052 - val_accuracy: 0.9917 - val_loss: 0.0564
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 81s 32ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9935 - val_loss: 0.0504
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9885 - val_loss: 0.0640
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 83s 33ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9907 - val_loss: 0.0698
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 55s 32ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9912 - val_loss: 0.0624
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9919 - loss: 0.0529
# Batch Size: 32, Epochs: 20
# Test Accuracy: 0.9919000267982483
#
# ==============================
# Training with Batch Size = 64, Epochs = 10
# ==============================
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 50s 58ms/step - accuracy: 0.9494 - loss: 0.1729 - val_accuracy: 0.9845 - val_loss: 0.0514
# Epoch 2/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 48s 57ms/step - accuracy: 0.9840 - loss: 0.0512 - val_accuracy: 0.9878 - val_loss: 0.0455
# Epoch 3/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 79s 54ms/step - accuracy: 0.9893 - loss: 0.0353 - val_accuracy: 0.9888 - val_loss: 0.0397
# Epoch 4/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9921 - loss: 0.0252 - val_accuracy: 0.9900 - val_loss: 0.0361
# Epoch 5/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 54ms/step - accuracy: 0.9933 - loss: 0.0205 - val_accuracy: 0.9910 - val_loss: 0.0305
# Epoch 6/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 50s 60ms/step - accuracy: 0.9946 - loss: 0.0165 - val_accuracy: 0.9895 - val_loss: 0.0370
# Epoch 7/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 79s 56ms/step - accuracy: 0.9960 - loss: 0.0119 - val_accuracy: 0.9905 - val_loss: 0.0366
# Epoch 8/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 56ms/step - accuracy: 0.9966 - loss: 0.0103 - val_accuracy: 0.9908 - val_loss: 0.0369
# Epoch 9/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9974 - loss: 0.0079 - val_accuracy: 0.9882 - val_loss: 0.0438
# Epoch 10/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 80s 53ms/step - accuracy: 0.9978 - loss: 0.0069 - val_accuracy: 0.9922 - val_loss: 0.0366
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9911 - loss: 0.0304
# Batch Size: 64, Epochs: 10
# Test Accuracy: 0.991100013256073
#
# ==============================
# Training with Batch Size = 64, Epochs = 15
# ==============================
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 48s 55ms/step - accuracy: 0.9494 - loss: 0.1683 - val_accuracy: 0.9837 - val_loss: 0.0550
# Epoch 2/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 83s 57ms/step - accuracy: 0.9836 - loss: 0.0520 - val_accuracy: 0.9877 - val_loss: 0.0422
# Epoch 3/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 79s 54ms/step - accuracy: 0.9893 - loss: 0.0350 - val_accuracy: 0.9887 - val_loss: 0.0415
# Epoch 4/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 48s 57ms/step - accuracy: 0.9915 - loss: 0.0265 - val_accuracy: 0.9902 - val_loss: 0.0327
# Epoch 5/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9932 - loss: 0.0204 - val_accuracy: 0.9885 - val_loss: 0.0422
# Epoch 6/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 54ms/step - accuracy: 0.9947 - loss: 0.0152 - val_accuracy: 0.9900 - val_loss: 0.0378
# Epoch 7/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 56ms/step - accuracy: 0.9955 - loss: 0.0129 - val_accuracy: 0.9892 - val_loss: 0.0427
# Epoch 8/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 80s 54ms/step - accuracy: 0.9965 - loss: 0.0099 - val_accuracy: 0.9895 - val_loss: 0.0363
# Epoch 9/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9974 - loss: 0.0080 - val_accuracy: 0.9915 - val_loss: 0.0400
# Epoch 10/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 82s 55ms/step - accuracy: 0.9978 - loss: 0.0067 - val_accuracy: 0.9915 - val_loss: 0.0346
# Epoch 11/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9976 - loss: 0.0068 - val_accuracy: 0.9922 - val_loss: 0.0339
# Epoch 12/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9910 - val_loss: 0.0421
# Epoch 13/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 82s 55ms/step - accuracy: 0.9983 - loss: 0.0049 - val_accuracy: 0.9923 - val_loss: 0.0397
# Epoch 14/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9902 - val_loss: 0.0530
# Epoch 15/15
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 45s 53ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9930 - val_loss: 0.0407
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9902 - loss: 0.0386
# Batch Size: 64, Epochs: 15
# Test Accuracy: 0.9901999831199646
#
# ==============================
# Training with Batch Size = 64, Epochs = 20
# ==============================
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)              │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_5 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 225,034 (879.04 KB)
#  Trainable params: 225,034 (879.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 48s 55ms/step - accuracy: 0.9473 - loss: 0.1743 - val_accuracy: 0.9860 - val_loss: 0.0513
# Epoch 2/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 48s 57ms/step - accuracy: 0.9846 - loss: 0.0507 - val_accuracy: 0.9892 - val_loss: 0.0419
# Epoch 3/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 81s 56ms/step - accuracy: 0.9890 - loss: 0.0347 - val_accuracy: 0.9892 - val_loss: 0.0415
# Epoch 4/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 82s 55ms/step - accuracy: 0.9919 - loss: 0.0269 - val_accuracy: 0.9907 - val_loss: 0.0342
# Epoch 5/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 56ms/step - accuracy: 0.9938 - loss: 0.0192 - val_accuracy: 0.9890 - val_loss: 0.0383
# Epoch 6/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 54ms/step - accuracy: 0.9948 - loss: 0.0162 - val_accuracy: 0.9915 - val_loss: 0.0335
# Epoch 7/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 56ms/step - accuracy: 0.9963 - loss: 0.0117 - val_accuracy: 0.9908 - val_loss: 0.0398
# Epoch 8/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9969 - loss: 0.0092 - val_accuracy: 0.9928 - val_loss: 0.0352
# Epoch 9/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 47s 55ms/step - accuracy: 0.9977 - loss: 0.0077 - val_accuracy: 0.9910 - val_loss: 0.0359
# Epoch 10/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 45s 54ms/step - accuracy: 0.9976 - loss: 0.0071 - val_accuracy: 0.9907 - val_loss: 0.0442
# Epoch 11/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9978 - loss: 0.0060 - val_accuracy: 0.9920 - val_loss: 0.0379
# Epoch 12/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 46s 55ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9883 - val_loss: 0.0543
# Epoch 13/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 95s 71ms/step - accuracy: 0.9981 - loss: 0.0055 - val_accuracy: 0.9880 - val_loss: 0.0672
# Epoch 14/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 70s 57ms/step - accuracy: 0.9981 - loss: 0.0054 - val_accuracy: 0.9922 - val_loss: 0.0482
# Epoch 15/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 50s 59ms/step - accuracy: 0.9988 - loss: 0.0035 - val_accuracy: 0.9910 - val_loss: 0.0565
# Epoch 16/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 79s 55ms/step - accuracy: 0.9989 - loss: 0.0035 - val_accuracy: 0.9905 - val_loss: 0.0495
# Epoch 17/20
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 48s 56ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9925 - val_loss: 0.0458
# Epoch 18/20
# 601/844 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - accuracy: 0.9993 - loss: 0.0023

# %%
import kagglehub
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# ==========================================
# 1. Download Dataset
# ==========================================
path = kagglehub.dataset_download("marquis03/cats-and-dogs")
print("Dataset Path:", path)

# ==========================================
# 2. Image Preprocessing
# ==========================================
img_size = 128
batch_sizes = [32, 64]
epochs_list = [10, 15]

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_data = datagen.flow_from_directory(
    path,
    target_size=(img_size, img_size),
    batch_size=32,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    path,
    target_size=(img_size, img_size),
    batch_size=32,
    class_mode='binary',
    subset='validation'
)

# ==========================================
# 3. Loop for Batch Size & Epochs
# ==========================================
for batch in batch_sizes:
    for ep in epochs_list:

        print("\n==============================")
        print(f"Batch Size = {batch}, Epochs = {ep}")
        print("==============================")

        # CNN Model
        model = Sequential([
            Conv2D(32, (3,3), activation='relu', input_shape=(img_size, img_size, 3)),
            MaxPooling2D((2,2)),

            Conv2D(64, (3,3), activation='relu'),
            MaxPooling2D((2,2)),

            Flatten(),

            Dense(128, activation='relu'),
            Dense(1, activation='sigmoid')   # Binary classification
        ])

        model.compile(
            optimizer='adam',
            loss='binary_crossentropy',
            metrics=['accuracy']
        )

        model.summary()

        # Train
        model.fit(
            train_data,
            validation_data=val_data,
            epochs=ep,
            batch_size=batch,
            verbose=1
        )

        # Evaluate
        loss, acc = model.evaluate(val_data)
        print(f"Accuracy: {acc}")
# Out:
# Downloading to /root/.cache/kagglehub/datasets/marquis03/cats-and-dogs/2.archive...
# 100%|██████████| 9.75M/9.75M [00:00<00:00, 91.9MB/s]
# Extracting files...
# Dataset Path: /root/.cache/kagglehub/datasets/marquis03/cats-and-dogs/versions/2
# Found 276 images belonging to 2 classes.
# Found 69 images belonging to 2 classes.
#
# ==============================
# Batch Size = 32, Epochs = 10
# ==============================
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,392,449 (28.20 MB)
#  Trainable params: 7,392,449 (28.20 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 903ms/step - accuracy: 0.7319 - loss: 0.9505 - val_accuracy: 0.7971 - val_loss: 0.5213
# Epoch 2/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 975ms/step - accuracy: 0.7971 - loss: 0.5086 - val_accuracy: 0.7971 - val_loss: 0.5357
# Epoch 3/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 975ms/step - accuracy: 0.7971 - loss: 0.5107 - val_accuracy: 0.7971 - val_loss: 0.5784
# Epoch 4/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 923ms/step - accuracy: 0.8007 - loss: 0.4956 - val_accuracy: 0.7971 - val_loss: 0.5090
# Epoch 5/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8007 - loss: 0.4482 - val_accuracy: 0.7971 - val_loss: 0.5017
# Epoch 6/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8188 - loss: 0.3948 - val_accuracy: 0.7971 - val_loss: 0.5034
# Epoch 7/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 852ms/step - accuracy: 0.8478 - loss: 0.3332 - val_accuracy: 0.8116 - val_loss: 0.4828
# Epoch 8/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9022 - loss: 0.2569 - val_accuracy: 0.7536 - val_loss: 0.5258
# Epoch 9/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9529 - loss: 0.1742 - val_accuracy: 0.7971 - val_loss: 0.5177
# Epoch 10/10
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 827ms/step - accuracy: 0.9891 - loss: 0.0963 - val_accuracy: 0.7826 - val_loss: 0.6092
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - accuracy: 0.7826 - loss: 0.6092
# Accuracy: 0.782608687877655
#
# ==============================
# Batch Size = 32, Epochs = 15
# ==============================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 126, 126, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 63, 63, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 61, 61, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 30, 30, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 57600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │     7,372,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,392,449 (28.20 MB)
#  Trainable params: 7,392,449 (28.20 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 993ms/step - accuracy: 0.5507 - loss: 1.1208 - val_accuracy: 0.7971 - val_loss: 0.5585
# Epoch 2/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.7971 - loss: 0.5473 - val_accuracy: 0.7971 - val_loss: 0.5256
# Epoch 3/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 783ms/step - accuracy: 0.7971 - loss: 0.4972 - val_accuracy: 0.7971 - val_loss: 0.5150
# Epoch 4/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 999ms/step - accuracy: 0.7971 - loss: 0.4708 - val_accuracy: 0.7971 - val_loss: 0.5174
# Epoch 5/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 930ms/step - accuracy: 0.8043 - loss: 0.4082 - val_accuracy: 0.7971 - val_loss: 0.5071
# Epoch 6/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 853ms/step - accuracy: 0.8949 - loss: 0.3180 - val_accuracy: 0.8116 - val_loss: 0.5252
# Epoch 7/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9167 - loss: 0.2262 - val_accuracy: 0.8116 - val_loss: 0.5440
# Epoch 8/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.9638 - loss: 0.1429 - val_accuracy: 0.7971 - val_loss: 0.9188
# Epoch 9/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 820ms/step - accuracy: 0.9529 - loss: 0.1573 - val_accuracy: 0.7971 - val_loss: 0.6758
# Epoch 10/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.9783 - loss: 0.0898 - val_accuracy: 0.7826 - val_loss: 0.6041
# Epoch 11/15
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 889ms/step - accuracy: 0.9928 - loss: 0.0516 - val_accuracy: 0.7246 - val_loss: 0.6695
# Epoch 12/15
# 5/9 ━━━━━━━━━━━━━━━━━━━━ 3s 819ms/step - accuracy: 0.9959 - loss: 0.0428
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_6807/1010738136.py in <cell line: 0>()
#      74
#      75         # Train
# ---> 76         model.fit(
#      77             train_data,
#      78             validation_data=val_data,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1686     cancellation_context = cancellation.context()
#    1687     if cancellation_context is None:
# -> 1688       outputs = execute.execute(
#    1689           name.decode("utf-8"),
#    1690           num_outputs=num_outputs,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
