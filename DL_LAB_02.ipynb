# %% [markdown]
# Step 1 — Change the epochs and observe the output (AND gate)

# %%
import numpy as np

x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])

epochs = 5
w, b = np.zeros(2), 0

for epoch in range(epochs):
    for x, y in zip(x_list, y_list):
        z = np.dot(x, w) + b
        y_pred = 1 if z >= 0 else 0
        E = y - y_pred
        print("error:", E, "<- at epoch", epoch)
        w += E * x
        b += E
        print(w, b)
# Out:
# error: -1 <- at epoch 0
# [0. 0.] -1
# error: 0 <- at epoch 0
# [0. 0.] -1
# error: 0 <- at epoch 0
# [0. 0.] -1
# error: 1 <- at epoch 0
# [1. 1.] 0
# error: -1 <- at epoch 1
# [1. 1.] -1
# error: -1 <- at epoch 1
# [1. 0.] -2
# error: 0 <- at epoch 1
# [1. 0.] -2
# error: 1 <- at epoch 1
# [2. 1.] -1
# error: 0 <- at epoch 2
# [2. 1.] -1
# error: -1 <- at epoch 2
# [2. 0.] -2
# error: -1 <- at epoch 2
# [1. 0.] -3
# error: 1 <- at epoch 2
# [2. 1.] -2
# error: 0 <- at epoch 3
# [2. 1.] -2
# error: 0 <- at epoch 3
# [2. 1.] -2
# error: -1 <- at epoch 3
# [1. 1.] -3
# error: 1 <- at epoch 3
# [2. 2.] -2
# error: 0 <- at epoch 4
# [2. 2.] -2
# error: -1 <- at epoch 4
# [2. 1.] -3
# error: 0 <- at epoch 4
# [2. 1.] -3
# error: 0 <- at epoch 4
# [2. 1.] -3

# %% [markdown]
# Step 2 — Use random weights and bias, observe convergence

# %%
import numpy as np

x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])

epochs = 5
w, b = np.random.randn(2), np.random.randn()

for epoch in range(epochs):
    for x, y in zip(x_list, y_list):
        z = np.dot(x, w) + b
        y_pred = 1 if z >= 0 else 0
        E = y - y_pred
        print("error:", E, "<- at epoch", epoch)
        w += E * x
        b += E
        print(w, b)
# Out:
# error: 0 <- at epoch 0
# [ 0.45395103 -1.34829732] -0.3355293116556118
# error: 0 <- at epoch 0
# [ 0.45395103 -1.34829732] -0.3355293116556118
# error: -1 <- at epoch 0
# [-0.54604897 -1.34829732] -1.3355293116556117
# error: 1 <- at epoch 0
# [ 0.45395103 -0.34829732] -0.33552931165561173
# error: 0 <- at epoch 1
# [ 0.45395103 -0.34829732] -0.33552931165561173
# error: 0 <- at epoch 1
# [ 0.45395103 -0.34829732] -0.33552931165561173
# error: -1 <- at epoch 1
# [-0.54604897 -0.34829732] -1.3355293116556117
# error: 1 <- at epoch 1
# [0.45395103 0.65170268] -0.33552931165561173
# error: 0 <- at epoch 2
# [0.45395103 0.65170268] -0.33552931165561173
# error: -1 <- at epoch 2
# [ 0.45395103 -0.34829732] -1.3355293116556117
# error: 0 <- at epoch 2
# [ 0.45395103 -0.34829732] -1.3355293116556117
# error: 1 <- at epoch 2
# [1.45395103 0.65170268] -0.33552931165561173
# error: 0 <- at epoch 3
# [1.45395103 0.65170268] -0.33552931165561173
# error: -1 <- at epoch 3
# [ 1.45395103 -0.34829732] -1.3355293116556117
# error: -1 <- at epoch 3
# [ 0.45395103 -0.34829732] -2.3355293116556117
# error: 1 <- at epoch 3
# [1.45395103 0.65170268] -1.3355293116556117
# error: 0 <- at epoch 4
# [1.45395103 0.65170268] -1.3355293116556117
# error: 0 <- at epoch 4
# [1.45395103 0.65170268] -1.3355293116556117
# error: -1 <- at epoch 4
# [0.45395103 0.65170268] -2.3355293116556117
# error: 1 <- at epoch 4
# [1.45395103 1.65170268] -1.3355293116556117

# %% [markdown]
# Step 3 — Add logic to stop when error becomes zero for all inputs

# %%
import numpy as np

x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])

epochs = 10
w, b = np.random.randn(2), np.random.randn()

for epoch in range(epochs):
    total_error = 0

    for x, y in zip(x_list, y_list):
        z = np.dot(x, w) + b
        y_pred = 1 if z >= 0 else 0
        E = y - y_pred
        total_error += abs(E)

        w += E * x
        b += E
        print("error:", E, "<- at epoch", epoch, w, b)

    if total_error == 0:
        print("Training converged at epoch", epoch)
        break
# Out:
# error: -1 <- at epoch 0 [-0.97154806 -0.37110034] -0.8606152343270809
# error: 0 <- at epoch 0 [-0.97154806 -0.37110034] -0.8606152343270809
# error: 0 <- at epoch 0 [-0.97154806 -0.37110034] -0.8606152343270809
# error: 1 <- at epoch 0 [0.02845194 0.62889966] 0.13938476567291913
# error: -1 <- at epoch 1 [0.02845194 0.62889966] -0.8606152343270809
# error: 0 <- at epoch 1 [0.02845194 0.62889966] -0.8606152343270809
# error: 0 <- at epoch 1 [0.02845194 0.62889966] -0.8606152343270809
# error: 1 <- at epoch 1 [1.02845194 1.62889966] 0.13938476567291913
# error: -1 <- at epoch 2 [1.02845194 1.62889966] -0.8606152343270809
# error: -1 <- at epoch 2 [1.02845194 0.62889966] -1.860615234327081
# error: 0 <- at epoch 2 [1.02845194 0.62889966] -1.860615234327081
# error: 1 <- at epoch 2 [2.02845194 1.62889966] -0.860615234327081
# error: 0 <- at epoch 3 [2.02845194 1.62889966] -0.860615234327081
# error: -1 <- at epoch 3 [2.02845194 0.62889966] -1.860615234327081
# error: -1 <- at epoch 3 [1.02845194 0.62889966] -2.860615234327081
# error: 1 <- at epoch 3 [2.02845194 1.62889966] -1.860615234327081
# error: 0 <- at epoch 4 [2.02845194 1.62889966] -1.860615234327081
# error: 0 <- at epoch 4 [2.02845194 1.62889966] -1.860615234327081
# error: -1 <- at epoch 4 [1.02845194 1.62889966] -2.860615234327081
# error: 1 <- at epoch 4 [2.02845194 2.62889966] -1.860615234327081
# error: 0 <- at epoch 5 [2.02845194 2.62889966] -1.860615234327081
# error: -1 <- at epoch 5 [2.02845194 1.62889966] -2.860615234327081
# error: 0 <- at epoch 5 [2.02845194 1.62889966] -2.860615234327081
# error: 0 <- at epoch 5 [2.02845194 1.62889966] -2.860615234327081
# error: 0 <- at epoch 6 [2.02845194 1.62889966] -2.860615234327081
# error: 0 <- at epoch 6 [2.02845194 1.62889966] -2.860615234327081
# error: 0 <- at epoch 6 [2.02845194 1.62889966] -2.860615234327081
# error: 0 <- at epoch 6 [2.02845194 1.62889966] -2.860615234327081
# Training converged at epoch 6

# %% [markdown]
# Step 4 — Repeat same process for OR gate

# %%
import numpy as np

x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,1])

epochs = 5
w, b = np.random.randn(2), np.random.randn()

for epoch in range(epochs):
    total_error = 0

    for x, y in zip(x_list, y_list):
        z = np.dot(x, w) + b
        y_pred = 1 if z >= 0 else 0
        E = y - y_pred
        total_error += abs(E)

        w += E * x
        b += E
        print("error:", E, "<- at epoch", epoch, w, b)

    if total_error == 0:
        print("OR gate converged at epoch", epoch)
        break
# Out:
# error: 0 <- at epoch 0 [ 1.1559314  -0.80311326] -0.5853463901949735
# error: 1 <- at epoch 0 [1.1559314  0.19688674] 0.4146536098050265
# error: 0 <- at epoch 0 [1.1559314  0.19688674] 0.4146536098050265
# error: 0 <- at epoch 0 [1.1559314  0.19688674] 0.4146536098050265
# error: -1 <- at epoch 1 [1.1559314  0.19688674] -0.5853463901949735
# error: 1 <- at epoch 1 [1.1559314  1.19688674] 0.4146536098050265
# error: 0 <- at epoch 1 [1.1559314  1.19688674] 0.4146536098050265
# error: 0 <- at epoch 1 [1.1559314  1.19688674] 0.4146536098050265
# error: -1 <- at epoch 2 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 2 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 2 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 2 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 3 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 3 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 3 [1.1559314  1.19688674] -0.5853463901949735
# error: 0 <- at epoch 3 [1.1559314  1.19688674] -0.5853463901949735
# OR gate converged at epoch 3

# %% [markdown]
# Step 5 — Try same for XOR gate (will NOT converge)

# %%
import numpy as np

x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,0])

epochs = 5
w, b = np.random.randn(2), np.random.randn()

for epoch in range(epochs):
    total_error = 0

    for x, y in zip(x_list, y_list):
        z = np.dot(x, w) + b
        y_pred = 1 if z >= 0 else 0
        E = y - y_pred
        total_error += abs(E)

        w += E * x
        b += E
        print("error:", E, "<- at epoch", epoch, w, b)

    if total_error == 0:
        print("XOR converged at epoch", epoch)
        break
# Out:
# error: -1 <- at epoch 0 [-0.68145109  0.87741456] 0.6001092576898113
# error: 0 <- at epoch 0 [-0.68145109  0.87741456] 0.6001092576898113
# error: 1 <- at epoch 0 [0.31854891 0.87741456] 1.6001092576898113
# error: -1 <- at epoch 0 [-0.68145109 -0.12258544] 0.6001092576898113
# error: -1 <- at epoch 1 [-0.68145109 -0.12258544] -0.39989074231018873
# error: 1 <- at epoch 1 [-0.68145109  0.87741456] 0.6001092576898113
# error: 1 <- at epoch 1 [0.31854891 0.87741456] 1.6001092576898113
# error: -1 <- at epoch 1 [-0.68145109 -0.12258544] 0.6001092576898113
# error: -1 <- at epoch 2 [-0.68145109 -0.12258544] -0.39989074231018873
# error: 1 <- at epoch 2 [-0.68145109  0.87741456] 0.6001092576898113
# error: 1 <- at epoch 2 [0.31854891 0.87741456] 1.6001092576898113
# error: -1 <- at epoch 2 [-0.68145109 -0.12258544] 0.6001092576898113
# error: -1 <- at epoch 3 [-0.68145109 -0.12258544] -0.39989074231018873
# error: 1 <- at epoch 3 [-0.68145109  0.87741456] 0.6001092576898113
# error: 1 <- at epoch 3 [0.31854891 0.87741456] 1.6001092576898113
# error: -1 <- at epoch 3 [-0.68145109 -0.12258544] 0.6001092576898113
# error: -1 <- at epoch 4 [-0.68145109 -0.12258544] -0.39989074231018873
# error: 1 <- at epoch 4 [-0.68145109  0.87741456] 0.6001092576898113
# error: 1 <- at epoch 4 [0.31854891 0.87741456] 1.6001092576898113
# error: -1 <- at epoch 4 [-0.68145109 -0.12258544] 0.6001092576898113
